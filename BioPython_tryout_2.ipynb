# %% [markdown]
# <a href="https://colab.research.google.com/github/florinabas/Bioinfo/blob/main/BioPython_tryout_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install Bio
import Bio
import os
# Get the current working directory
cwd = os.getcwd()
from Bio import AlignIO
import os
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 321.3/321.3 kB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 67.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.7/46.7 kB 4.5 MB/s eta 0:00:00
# ...

# %%
cwd = os.getcwd() # Get the current working directory
print(cwd)
from google.colab import files
uploaded=files.upload
# Out:
# /content

# %%
# create a set of many resampled alignments using bootstrapping from Bio.AlignIO
alignments = AlignIO.parse('resampled.phy', 'phylip')
for alignment in alignments:
    print(alignment)
    print()
# Out:
# Alignment with 5 rows and 6 columns
# AAACCA Alpha
# AAACCC Beta
# ACCCCA Gamma
# CCCAAC Delta
# CCCAAA Epsilon
#
# Alignment with 5 rows and 6 columns
# AAACAA Alpha
# AAACCC Beta
# ACCCAA Gamma
# CCCACC Delta
# CCCAAA Epsilon
#
# Alignment with 5 rows and 6 columns
# AAAAAC Alpha
# AAACCC Beta
# AACAAC Gamma
# CCCCCA Delta
# CCCAAC Epsilon
#
# Alignment with 5 rows and 6 columns
# AAAACC Alpha
# ACCCCC Beta
# AAAACC Gamma
# CCCCAA Delta
# CAAACC Epsilon

# %%
# keep all the alignments in memory at once by turning the iterator into a list
alignments = list(AlignIO.parse("resampled.phy", "phylip"))
last_align = alignments[-1]
first_align = alignments[0]
print(first_align)
print(last_align)
# Out:
# Alignment with 5 rows and 6 columns
# AAACCA Alpha
# AAACCC Beta
# ACCCCA Gamma
# CCCAAC Delta
# CCCAAA Epsilon
# Alignment with 5 rows and 6 columns
# AAAACC Alpha
# ACCCCC Beta
# AAAACC Gamma
# CCCCAA Delta
# CAAACC Epsilon
